# %%
import cv2

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
im = cv2.imread('lena.png')

# %%
im.shape
# Out:
# (252, 257, 3)

# %%
rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %%
gray = cv2.cvtColor(rgb, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
plt.imshow(im)

# %%
rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb)

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
crop = im[50:-50, 50:-50, :]

# %%
plt.imshow(crop)

# %%
crop_2 = crop[50:-50, 50:-50, :]

# %%
plt.imshow(crop_2)

# %%
crop = im[50:-50, 50:-50,:]

# %%
plt.imshow(crop)

# %%
cv2.imwrite('mako.png',crop)
# Out:
# True

# %%
crop_rgb = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
plt.imshow(crop_rgb)

# %%
import numpy as np

# %%
np.save('makofff.png', crop_rgb)

# %% [markdown]
# # Binarization

# %%
plt.imshow(gray, cmap='gray')

# %%
retval,dist =cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# %%
retval
# Out:
# 127.0

# %%
dist
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(dist)

# %%
retval, dist = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# %%
retval
# Out:
# 127.0

# %%
plt.imshow(dist)

# %% [markdown]
# ## Ootsu

# %%
im = cv2.imread('bimodel.png')
gray = cv2.cvtColor(im, cv2.COLO)

# %%
im = cv2.imread('bimodel.png')
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
im.shape
# Out:
# (252, 370, 3)

# %%
plt.imshow(im)

# %%
sns.displot(gray)
sns.vlines(retval, 0, 0.01, 'r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-010edf33b145> in <module>
#       1 sns.displot(gray)
# ----> 2 sns.vlines(retval, 0, 0.01, 'r')
#
# AttributeError: module 'seaborn' has no attribute 'vlines'

# %%
retval, dist = cv2.threshold(gray, 0,255, cv2.THRESH_BINARY+cv2.)

# %%
plt.imshow(dist)

# %%
retval, dist = cv2.threshold(gray, 0,255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
retval
# Out:
# 152.0

# %%
dist
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(dist, cmap='gray')

# %%
cv2.threshold(gray, 0, 255, cv2.T)

# %% [markdown]
# # cv2.adaptive

# %%
im = plt.imread('text.png')

# %%
plt.imshow(im)

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.4.1-cp38-cp38-macosx_10_11_x86_64.whl (173.9 MB)
# ...
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached wrapt-1.12.1-cp38-cp38-macosx_10_9_x86_64.whl
# ...
#   Using cached protobuf-3.15.8-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
# ...
#   Using cached grpcio-1.32.0-cp38-cp38-macosx_10_9_x86_64.whl (3.3 MB)
# ...
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# ...
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached tensorboard_data_server-0.6.0-py3-none-macosx_10_9_x86_64.whl (2.8 MB)
# ...

# %%
import nibabel as nib
